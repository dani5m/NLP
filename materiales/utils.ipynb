# %% [markdown]
# # **Useful functions for your lab assigments**

# %% [markdown]
# **numpy.argmax: Returns the indices of the maximum values along an axis. https://numpy.org/doc/stable/reference/generated/numpy.argmax.html**

# %%
import numpy as np
array = np.random.rand(10)
print ("Sample array")
print (array)
idxmax = np.argmax(array)
print ("Index {} has the highest value ({}) of the array".format(idxmax, array[idxmax]))
# Out:
# Sample array
# [0.3969436  0.67702017 0.29870533 0.54558195 0.88313119 0.50386943
#  0.57736442 0.65450851 0.27435055 0.27852383]
# Index 4 has the highest value (0.8831311934340972) of the array

# %% [markdown]
# **np.argsort: Returns the indices that would sort an array.**

# %%
# Creando un array de muestra con 10 números aleatorios
array = np.random.rand(10)
print("Sample array:")
print(array)

# Utilizamos argsort para obtener los índices que ordenarían el array,
# y luego seleccionamos los últimos tres índices para obtener los tres valores más altos
idxs_ordenados = np.argsort(array)
print(idxs_ordenados)
top_3_idxs = idxs_ordenados[-3:]  # Índices de los tres valores más altos

# Imprimimos los índices y los valores correspondientes
print("Indices of the three highest values:", top_3_idxs)
print("Three highest values:", array[top_3_idxs])
# Out:
# Sample array:
# [0.13293597 0.81907168 0.8178549  0.7924505  0.29692674 0.56544229
#  0.53524539 0.11380127 0.31297226 0.43090742]
# [7 0 4 8 9 6 5 3 2 1]
# Indices of the three highest values: [3 2 1]
# Three highest values: [0.7924505  0.8178549  0.81907168]

# %%
import time
import tqdm

for i in tqdm.tqdm(range(1000)):
  time.sleep(0.005)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# 100%|██████████| 1000/1000 [00:05<00:00, 185.84it/s]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding


#Definimos un modelo de juguete para ver cómo acceder a los vectores de la capa
#embeddings
capa_embedding = Embedding(input_dim=1000, output_dim=64, name='nombre_capa_embedding')
modelo = Sequential([capa_embedding])

# Extraer los pesos de la capa de Embedding, que son los embeddings
# Aquí no estamos entrenando el modelo, así que los embeddings serán aleatorios
embeddings = capa_embedding.get_weights()[0]

# Supongamos que queremos la embedding de la palabra con ID 'word_id'
word_id = 42
word_embedding = embeddings[word_id]

print(f"Embedding para la palabra con ID {word_id}: {word_embedding}")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 12
#       8 modelo = Sequential([capa_embedding])
#      10 # Extraer los pesos de la capa de Embedding, que son los embeddings
#      11 # Aquí no estamos entrenando el modelo, así que los embeddings serán aleatorios
# ---> 12 embeddings = capa_embedding.get_weights()[0]
#      14 # Supongamos que queremos la embedding de la palabra con ID 'word_id'
#      15 word_id = 42
#
# IndexError: list index out of range

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding

# Definimos la capa
capa_embedding = Embedding(input_dim=1000, output_dim=64, name='nombre_capa_embedding')
modelo = Sequential([capa_embedding])

# ⚠️ Paso necesario: ejecutar al menos una inferencia para inicializar la capa
_ = modelo(np.array([[0]]))  # cualquier valor válido funciona

# Ahora sí: extraemos los pesos
embeddings = capa_embedding.get_weights()[0]

# Obtener embedding de la palabra con ID 42
word_id = 42
word_embedding = embeddings[word_id]

print(f"Embedding para la palabra con ID {word_id}: {word_embedding}")
# Out:
# Embedding para la palabra con ID 42: [-0.03714063 -0.01706303  0.02067733  0.00666     0.04022565 -0.00436621
#  -0.04813348 -0.02273989 -0.04401575 -0.02463882  0.04634403 -0.00370406
#   0.02462497  0.03858379 -0.03981861 -0.0155529   0.02259699  0.01144664
#  -0.03981545 -0.03041136 -0.04332513  0.01710382 -0.01901478  0.02669031
#  -0.03187018  0.01586339  0.04458631  0.02627101 -0.02884939 -0.04834744
#  -0.01996821 -0.0203156  -0.01874355  0.01478967  0.02574864 -0.04130325
#   0.00710972  0.04180001 -0.01788142  0.0025803   0.00833708  0.02091898
#   0.00484531 -0.04660851  0.01591467  0.00064664  0.02127803  0.04520288
#   0.04776521 -0.037429   -0.03060067 -0.01212953  0.02962167  0.00282929
#  -0.00603843  0.00857504  0.04561334 -0.01719662  0.03686957  0.0216114
#   0.02536782 -0.00399139 -0.04293629  0.02614364]
